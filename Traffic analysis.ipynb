# %%
ls
# Out:
#  data/  'Traffic analysis.ipynb'   web_traffic.tsv*  'Работа с массивами.ipynb'

# %%
import scipy as sp
data = sp.genfromtxt("web_traffic.tsv", delimiter="\t") # file is read

# %%
print(data[:743])
# Out:
# [[1.000e+00 2.272e+03]
#  [2.000e+00       nan]
#  [3.000e+00 1.386e+03]
#  ...
#  [7.410e+02 5.392e+03]
#  [7.420e+02 5.906e+03]
#  [7.430e+02 4.881e+03]]

# %%
x = data[:,0] #data division on the vectors
y = data[:,1]

# %%
sp.sum(sp.isnan(y)) #8 elements is "nan"
# Out:
# 8

# %%
 #select elements with numbers
x = x[~sp.isnan(y)]
y = y[~sp.isnan(y)]

# %%
x.shape
# Out:
# (735,)

# %%
y.shape
# Out:
# (735,)

# %%
import matplotlib.pyplot as plt  # view data

# %%
plt.scatter (x,y, s=10)
plt.title("Web traffic over the last month")
plt.xlabel("Time")
plt.ylabel("Hits/hour")
plt.xticks([w*7*24 for w in range(10)], ['week %i' % w for w in range(10) ])
plt.autoscale(tight = True)
plt.grid (True, linestyle = '-', color = '0.75')
fx=sp.linspace(0,x[-1],1000)
plt.plot(fx,f1(fx),linewidth=4)
plt.legend(["d=%i" % f1.order], loc="upper left")

plt.show()

# %%
fp1, residuals, rank, sv, rcond = sp.polyfit(x, y, 1, full=True)

# %%
y.shape
# Out:
# (735,)

# %%
print("Параметры: %s" %fp1)
# Out:
# Параметры: [  2.59619213 989.02487106]

# %%
print(residuals)
# Out:
# [3.17389767e+08]

# %%
f1 = sp.poly1d(fp1)
print("Error of the model of fp1:", residuals)

fp2, res2, rank2, sv2, rcond2 = sp.polyfit(x, y, 2, full=True)
print("Model parameters of fp2: %s" % fp2)
print("Error of the model of fp2:", res2)
f2 = sp.poly1d(fp2)
# Out:
# Error of the model of fp1: [3.17389767e+08]
# Model parameters of fp2: [ 1.05322215e-02 -5.26545650e+00  1.97476082e+03]
# Error of the model of fp2: [1.79983508e+08]

# %%
f3 = sp.poly1d(sp.polyfit(x, y, 3))
f10 = sp.poly1d(sp.polyfit(x, y, 10))
f100 = sp.poly1d(sp.polyfit(x, y, 100))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RankWarning: Polyfit may be poorly conditioned
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.scatter (x,y, s=10)
plt.title("Web traffic over the last month")
plt.xlabel("Time")
plt.ylabel("Hits/hour")
plt.xticks([w*7*24 for w in range(10)], ['week %i' % w for w in range(10) ])
plt.autoscale(tight = True)
plt.grid (True, linestyle = '-', color = '0.75')
fx=sp.linspace(0,x[-1],1000)
plt.plot(fx,f1(fx),linewidth=4)
plt.legend(["d=%i" % f1.order], loc="upper left")
plt.plot(fx,f2(fx),linewidth=4)
plt.legend(["d=%i" % f2.order], loc="upper left")
plt.show()

# %%
x = x.astype(int)

# %%
y = y.astype(int)

# %%
# Out:
# 588

# %%
inflection=588

xa = x[:inflection]
ya = y[:inflection]
xb = x[inflection:]
yb = y[inflection:]

f1 = sp.poly1d(sp.polyfit(xa, ya, 1))
f2 = sp.poly1d(sp.polyfit(xb, yb, 1))

# %%
plt.scatter (x,y, s=10)
plt.title("Web traffic over the last month")
plt.xlabel("Time")
plt.ylabel("Hits/hour")
plt.xticks([w*7*24 for w in range(10)], ['week %i' % w for w in range(10) ])
plt.autoscale(tight = True)
plt.grid (True, linestyle = '-', color = '0.75')
fx=sp.linspace(0,x[-1],1000)
plt.plot(fx,f1(fx),linewidth=4)
plt.legend(["d=%i" % f1.order], loc="upper left")
plt.plot(fx,f2(fx),linewidth=4)
plt.legend(["d=%i" % f2.order], loc="upper left")
plt.show()
